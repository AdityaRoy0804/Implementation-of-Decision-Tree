# %% [markdown]
# # IMPLEMENTATION OF DECISION TREE

# %% [markdown]
# ## DECISISON TREE FOR REGRESSION

# %% [raw]
# A Decision Tree Regressor predicts continuous numerical values by learning decision rules from features.
#     1.Splits the data based on feature values to reduce variance.
#     2.At each node, it chooses the best split by minimizing Mean Squared Error (MSE) or another regression loss.
#     3.Recursively splits until:
#         A.Max depth is reached
#         B.Minimum samples per leaf is met
#         C.Or no further gain is possible
#     4.Each leaf node predicts the average of the target values in that node.

# %% [markdown]
# ### Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading the datasets

# %%
data = pd.read_csv(r"C:\Users\DJ COMPUTERS\OneDrive\Desktop\Jupyter\House Price Prediction Dataset.csv")
data.head(10)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 0   1  1360         5          4       3       1970  Downtown  Excellent
# 1   2  4272         5          4       3       1958  Downtown  Excellent
# 2   3  3592         2          2       3       1938  Downtown       Good
# 3   4   966         4          2       2       1902  Suburban       Fair
# 4   5  4926         1          4       2       1975  Downtown       Fair
# 5   6  3944         1          2       1       1906     Urban       Poor
# 6   7  3671         1          1       2       1948     Rural       Poor
# 7   8  3419         2          4       1       1925  Suburban       Good
# 8   9   630         2          2       1       1932     Rural       Poor
# 9  10  2185         3          3       1       2000  Downtown       Poor
#
#   Garage   Price
# 0     No  149919
# 1     No  424998
# 2     No  266746
# 3    Yes  244020
# 4    Yes  636056
# 5     No   93262
# 6    Yes  448722
# 7    Yes  594893
# 8    Yes  652878
# 9     No  340375

# %% [markdown]
# ### Data Pre-processing

# %%
data.isna().sum()   # checking for na values
# Out:
# Id           0
# Area         0
# Bedrooms     0
# Bathrooms    0
# Floors       0
# YearBuilt    0
# Location     0
# Condition    0
# Garage       0
# Price        0
# dtype: int64

# %%
data.isnull()  # checking for null values
# Out:
#          Id   Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  \
# 0     False  False     False      False   False      False     False
# 1     False  False     False      False   False      False     False
# 2     False  False     False      False   False      False     False
# 3     False  False     False      False   False      False     False
# 4     False  False     False      False   False      False     False
# ...     ...    ...       ...        ...     ...        ...       ...
# 1995  False  False     False      False   False      False     False
# 1996  False  False     False      False   False      False     False
# 1997  False  False     False      False   False      False     False
# 1998  False  False     False      False   False      False     False
# 1999  False  False     False      False   False      False     False
#
#       Condition  Garage  Price
# 0         False   False  False
# 1         False   False  False
# 2         False   False  False
# 3         False   False  False
# 4         False   False  False
# ...         ...     ...    ...
# 1995      False   False  False
# 1996      False   False  False
# 1997      False   False  False
# 1998      False   False  False
# 1999      False   False  False
#
# [2000 rows x 10 columns]

# %%
data.duplicated()   # checking for duplicate records
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
data.shape   # dimensions of the data
# Out:
# (2000, 10)

# %%
data = data.drop(columns = "Id")

# %% [markdown]
# # Data Mining

# %%
data.info()   # overview of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Area       2000 non-null   int64
#  1   Bedrooms   2000 non-null   int64
#  2   Bathrooms  2000 non-null   int64
#  3   Floors     2000 non-null   int64
#  4   YearBuilt  2000 non-null   int64
#  5   Location   2000 non-null   object
#  6   Condition  2000 non-null   object
#  7   Garage     2000 non-null   object
#  8   Price      2000 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 140.8+ KB

# %%
data["Location"].value_counts()
# Out:
# Location
# Downtown    558
# Urban       485
# Suburban    483
# Rural       474
# Name: count, dtype: int64

# %%
data["Condition"].value_counts()
# Out:
# Condition
# Fair         521
# Excellent    511
# Poor         507
# Good         461
# Name: count, dtype: int64

# %%
data["Garage"].value_counts()
# Out:
# Garage
# No     1038
# Yes     962
# Name: count, dtype: int64

# %%
data.describe()   # summary statistics of the data
# Out:
#               Area     Bedrooms   Bathrooms       Floors    YearBuilt  \
# count  2000.000000  2000.000000  2000.00000  2000.000000  2000.000000
# mean   2786.209500     3.003500     2.55250     1.993500  1961.446000
# std    1295.146799     1.424606     1.10899     0.809188    35.926695
# min     501.000000     1.000000     1.00000     1.000000  1900.000000
# 25%    1653.000000     2.000000     2.00000     1.000000  1930.000000
# 50%    2833.000000     3.000000     3.00000     2.000000  1961.000000
# 75%    3887.500000     4.000000     4.00000     3.000000  1993.000000
# max    4999.000000     5.000000     4.00000     3.000000  2023.000000
#
#                Price
# count    2000.000000
# mean   537676.855000
# std    276428.845719
# min     50005.000000
# 25%    300098.000000
# 50%    539254.000000
# 75%    780086.000000
# max    999656.000000

# %% [markdown]
# ### Feature Engineering

# %%
# Label encode categorical columns
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in data.select_dtypes(include="object").columns:
    data[col] = le.fit_transform(data[col])

# %%
# Correlation Analysis

# Correlation with the target variable
correlation = data.corr(numeric_only=True)["Price"].sort_values(ascending=False)
correlation
# Select features with correlation > threshold
threshold = 0.0
important_features = correlation[abs(correlation) > threshold].index.tolist()
# Separate features and target
features_to_scale = [col for col in important_features if col != "Price"]

# %%
# Apply MinMax scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaled_array = scaler.fit_transform(data[features_to_scale])

# Create new scaled DataFrame
scaled_data = pd.DataFrame(scaled_array, columns=features_to_scale)

# Add target column back
scaled_data["Price"] = data["Price"].values

# Final engineered data
scaled_data.head()
# Out:
#    Floors  YearBuilt  Garage      Area  Bedrooms  Location  Condition  \
# 0     1.0   0.569106     0.0  0.190974      1.00  0.000000   0.000000
# 1     1.0   0.471545     0.0  0.838373      1.00  0.000000   0.000000
# 2     1.0   0.308943     0.0  0.687194      0.25  0.000000   0.666667
# 3     0.5   0.016260     1.0  0.103379      0.75  0.666667   0.333333
# 4     0.5   0.609756     1.0  0.983771      0.00  0.000000   0.333333
#
#    Bathrooms   Price
# 0   1.000000  149919
# 1   1.000000  424998
# 2   0.333333  266746
# 3   0.333333  244020
# 4   1.000000  636056

# %%
data = scaled_data
data.head()   ## final data for model fitting
# Out:
#    Floors  YearBuilt  Garage      Area  Bedrooms  Location  Condition  \
# 0     1.0   0.569106     0.0  0.190974      1.00  0.000000   0.000000
# 1     1.0   0.471545     0.0  0.838373      1.00  0.000000   0.000000
# 2     1.0   0.308943     0.0  0.687194      0.25  0.000000   0.666667
# 3     0.5   0.016260     1.0  0.103379      0.75  0.666667   0.333333
# 4     0.5   0.609756     1.0  0.983771      0.00  0.000000   0.333333
#
#    Bathrooms   Price
# 0   1.000000  149919
# 1   1.000000  424998
# 2   0.333333  266746
# 3   0.333333  244020
# 4   1.000000  636056

# %% [markdown]
# ### Model Training

# %%
## Feature and Label Separation

X = data.drop(columns = "Price",axis =1)
Y = data["Price"]

## Train test splitting
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.2,random_state = 42)

# %%
## fitting the model

from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor(max_depth = None,random_state=42)
reg.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %% [markdown]
# ### Model Evaluation

# %%
from sklearn.metrics import root_mean_squared_error, r2_score
y_pred = reg.predict(X_test)

# Evaluation
print("Mean Squared Error:", root_mean_squared_error(Y_test, y_pred))
print("R² Score:", r2_score(Y_test, y_pred))
# Out:
# Mean Squared Error: 410219.4376555431
# R² Score: -1.1630144082103673
